# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import aiohttp
import asyncio
from tqdm import tqdm # adds progress bar 
import urllib.parse # extract candidate ID
# Out:
# C:\Users\fenlo\AppData\Roaming\Python\Python37\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (4.0.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ### code to get all 20_000 links in this
#
# Takes about 14 minutes
#
# Although, there appears to be other links that are not sequential. such as Councilor Rory O'Connor: https://www.irelandelection.com/candidate.php?candid=18829

# %%
number_of_links = 20000
failed = [] # list to store failed attempts
my_timeout = aiohttp.ClientTimeout(
    total=None, # default value is 5 minutes, set to `None` for unlimited timeout
    sock_connect=150, # How long to wait before an open socket allowed to connect
    sock_read=150 # How long to wait with no data being read before timing out
)

client_args = dict(
    trust_env=True,
    timeout=my_timeout
)


async def fetch(session, url, pbar):
    """Fetch a url, using specified ClientSession."""
    async with session.get(url) as response:
        try:
            resp = await response.read()
            pbar.update(1)
            return (url, resp)
        except asyncio.TimeoutError:
            failed.append(url)
            print('timeout')
            pbar.update(1)
            return {"results": f"timeout error on {url}"}
        if response.status != 200:
            failed.append(url)
            print('error')
            pbar.update(1)
            return {"error": f"server returned {response.status}"}

async def get_responses(session, pbar):
    tasks = []
    for i in range(1, number_of_links):
        url = f'https://www.irelandelection.com/candidate.php?candid={i}'
        tasks.append(fetch(session, url, pbar))
    responses = await asyncio.gather(*tasks, return_exceptions=True)
    return responses

connector = aiohttp.TCPConnector(limit=60)
async with aiohttp.ClientSession(connector=connector,**client_args) as s:
    with tqdm(total=number_of_links) as pbar:
        responses = await get_responses(s, pbar)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████▉| 19999/20000 [06:57<00:00, 47.89it/s]

# %%
len(failed)
# Out:
# 0

# %%
print('Failed on these links:\n',failed)
# Out:
# Failed on these links:
#  []

# %% [markdown]
# ### Functions for getting data from the page

# %%
def get_candidate_name(soup):
    name = soup.find('title').text.split(' - ')[0].strip()
    return name

def get_election_type(election_string):
    election_string = election_string.lower()
    if 'local election' in election_string:
        return 'LOCAL'
    elif 'general election' in election_string:
        return 'GENERAL'
    elif 'european election' in election_string:
        return 'EUROPEAN'
    elif 'presidential election' in election_string:
        return 'PRESIDENTIAL'
    elif 'by-election' in election_string:
        return 'BI-ELECTION'
    
def get_constituency_name(election_string):
    constituency =  election_string.split(' - ')[1].strip()
    return constituency

def process_row(row):
    d = {}
    count = 0
    column_names = ['election','first_pref_pct','first_pref_count','first_pref_quota_ratio','elected']
    for td in row.find_all('td'):
        txt = td.text
        if txt:
            d[column_names[count]] = txt.strip()
            count+=1
            d['elected'] = True if td.find('img') else False
        elif td.find('img').get('title'):
            d['party'] = td.find('img').get('title')
    return d
    
def extract_table(soup):
    list_of_rows = []
    table_body = soup.find('tbody')
    if not table_body:
        raise Exception('No Table Found')
    rows = table_body.find_all('tr')
    for row in rows:
        d = process_row(row)
        list_of_rows.append(d)
    return list_of_rows

def create_dataframe(name,list_of_rows,candid_id):
    df = pd.DataFrame(list_of_rows)
    df['elected'] = df.elected.fillna(False)
    df['year'] = df.election.apply(lambda election_string: int(election_string[:4]))
    df['candidate'] = name
    df['constituency'] = df.election.apply(get_constituency_name)
    df['election_type'] = df.election.apply(get_election_type)
    df['candid_id'] = candid_id
    return df

def extract_data_from_page(res,candid_id):
    soup = BeautifulSoup(res)
    if len(list(soup.stripped_strings)) == 3:
        raise Exception('Empty Page')
    name = get_candidate_name(soup)
    rows = extract_table(soup)
    df = create_dataframe(name,rows,candid_id)
    return df

def get_candid_id(url) :
    
    parsed_url = urllib.parse.urlparse(url)
    query_string = parsed_url.query
    query_string_dict = urllib.parse.parse_qs(query_string)
    candid_id = query_string_dict['candid'][0]
    
    return candid_id

#extract_data_from_page()

# %%
list_of_dataframes = []
fails = []
for (url,resp) in responses:
    #print(url)
    try:
        candid_id = get_candid_id(url) # getting the id from url 
        dataframe = extract_data_from_page(resp,candid_id)
        list_of_dataframes.append(dataframe)
    except Exception as e: 
        print('Failed:',url)
        print(e,'\n------------------------')
        if str(e) == 'No Table Found':
            fails.append((url,resp))

# %% [markdown]
# have to run throught the failed ones before concatinating the dataframes.
#
# Fails happen for 2 reasons:
# - The page is empty eg: https://www.irelandelection.com/candidate.php?candid=30
# - The page didnt return anything because I sent so many requests that their server couldnt respond.
#
# We send the requests back through again for the failed because of lack of tables

# %%
fails2 = []
tasks = []

connector = aiohttp.TCPConnector(limit=60)
async with aiohttp.ClientSession(connector=connector,**client_args) as s:
    for (url,resp) in fails:
        tasks.append(fetch(s,url)) 
    responses2 = await asyncio.gather(*tasks, return_exceptions=True)


for (url,resp) in responses2:
    #print(url)
    try:
        dataframe = extract_data_from_page(resp)
        list_of_dataframes.append(dataframe)
    except Exception as e: 
        print('Failed:',url)
        print(e,'\n------------------------')
        if str(e) == 'No Table Found':
            fails2.append(
                (url,resp)
                )

# %%
print(fails2)
# Out:
# []

# %%
DF = pd.concat(list_of_dataframes)
DF.dtypes
# Out:
# election                  object
# elected                     bool
# party                     object
# first_pref_pct            object
# first_pref_count          object
# first_pref_quota_ratio    object
# year                       int64
# candidate                 object
# constituency              object
# election_type             object
# candid_id                 object
# dtype: object

# %%
DF['first_pref_pct'] = DF['first_pref_pct'].replace('Candidate for forthcoming election',None)
DF['first_pref_pct'] = DF['first_pref_pct'].str.replace('%','').astype(float)/100
DF['first_pref_count'] = DF.first_pref_count.fillna(0).astype(int)
DF['first_pref_quota_ratio'] = DF.first_pref_quota_ratio.astype(float)
DF.dtypes
# Out:
# election                   object
# elected                      bool
# party                      object
# first_pref_pct            float64
# first_pref_count            int32
# first_pref_quota_ratio    float64
# year                        int64
# candidate                  object
# constituency               object
# election_type              object
# candid_id                  object
# dtype: object

# %%
DF = DF.reset_index().drop(columns=['index'])

# %%
DF.to_parquet('ALL_CANDIDATES.parquet')

# %% [markdown]
# For every elections we want
# - Number of Constituencies
# - How many consituency do we have vote data on?
# - What was the quota?
# - What was the votes/quota in first count?
# - What was the lowest votes/quota?
# - What was the highest votes/quota?
# - Who transfered to who (if you have transfer data)

# %%
DF.head(50)
# Out:
#                                         election  elected         party  \
# 0               2004 Local Election - Thomastown     True  Labour Party
# 1               2009 Local Election - Thomastown     True  Labour Party
# 2        2011 general election - Carlow–Kilkenny     True  Labour Party
# 3        2016 general election - Carlow–Kilkenny    False  Labour Party
# 0  1982 (Feb) general election - Carlow–Kilkenny    False   Fianna Fáil
# 1                1985 Local Election - Tullaroan    False   Fianna Fáil
# 2                1991 Local Election - Tullaroan     True   Fianna Fáil
# 3        1997 general election - Carlow–Kilkenny     True   Fianna Fáil
# 4                 1999 Local Election - Kilkenny     True   Fianna Fáil
# 5        2002 general election - Carlow–Kilkenny     True   Fianna Fáil
# 6        2007 general election - Carlow–Kilkenny     True   Fianna Fáil
# 7        2011 general election - Carlow–Kilkenny     True   Fianna Fáil
# 8        2016 general election - Carlow–Kilkenny     True   Fianna Fáil
# 9        2020 General Election - Carlow–Kilkenny     True   Fianna Fáil
# 0                  1999 Local Election - Piltown     True     Fine Gael
# 1        2007 general election - Carlow–Kilkenny    False     Fine Gael
# 2                  2009 European Election - East    False     Fine Gael
# 3        2011 general election - Carlow–Kilkenny     True     Fine Gael
# 4        2016 general election - Carlow–Kilkenny     True     Fine Gael
# 5        2020 General Election - Carlow–Kilkenny     True     Fine Gael
# 0                1985 Local Election - Tullaroan     True     Fine Gael
# 1        1987 general election - Carlow–Kilkenny    False     Fine Gael
# 2        1989 general election - Carlow–Kilkenny     True     Fine Gael
# 3                1991 Local Election - Tullaroan     True     Fine Gael
# 4        1992 general election - Carlow–Kilkenny     True     Fine Gael
# 5        1997 general election - Carlow–Kilkenny     True     Fine Gael
# 6                 1999 Local Election - Kilkenny     True     Fine Gael
# 7        2002 general election - Carlow–Kilkenny     True     Fine Gael
# 8        2007 general election - Carlow–Kilkenny     True     Fine Gael
# 9        2011 general election - Carlow–Kilkenny     True     Fine Gael
# 0                   2009 Local Election - Tullow     True     Fine Gael
# 1        2011 general election - Carlow–Kilkenny     True     Fine Gael
# 2        2016 general election - Carlow–Kilkenny     True     Fine Gael
# 3        2020 General Election - Carlow–Kilkenny    False     Fine Gael
# 0                  1999 Local Election - Piltown     True   Fianna Fáil
# 1                  2004 Local Election - Piltown     True   Fianna Fáil
# 2        2007 general election - Carlow–Kilkenny     True   Fianna Fáil
# 3        2011 general election - Carlow–Kilkenny    False   Fianna Fáil
# 4             2015 by-election - Carlow–Kilkenny     True   Fianna Fáil
# 5        2016 general election - Carlow–Kilkenny     True   Fianna Fáil
# 6        2020 General Election - Carlow–Kilkenny    False   Fianna Fáil
# 0        2007 general election - Carlow–Kilkenny    False     Sinn Féin
# 1                  2009 European Election - East    False     Sinn Féin
# 2                 2009 Local Election - Kilkenny    False     Sinn Féin
# 3        2011 general election - Carlow–Kilkenny    False     Sinn Féin
# 4       2014 Local Election - Kilkenny City-West     True     Sinn Féin
# 5             2015 by-election - Carlow–Kilkenny    False     Sinn Féin
# 6        2016 general election - Carlow–Kilkenny     True     Sinn Féin
# 7        2020 General Election - Carlow–Kilkenny     True     Sinn Féin
# 0             1999 Local Election - Carlow No. 2    False   Fianna Fáil
#
#    first_pref_pct  first_pref_count  first_pref_quota_ratio  year  \
# 0           0.085               641                    0.51  2004
# 1           0.156              1183                    0.78  2009
# 2           0.109              8072                    0.66  2011
# 3           0.063              4391                    0.38  2016
# 0           0.017               907                    0.10  1982
# 1           0.121               550                    0.61  1985
# 2           0.121               633                    0.61  1991
# 3           0.106              5990                    0.64  1997
# 4           0.194              1678                    1.55  1999
# 5           0.154              9343                    0.77  2002
# 6           0.172             11635                    1.03  2007
# 7           0.129              9531                    0.78  2011
# 8           0.150             10528                    0.90  2016
# 9           0.143             10558                    0.86  2020
# 0           0.109               718                    0.76  1999
# 1           0.096              6494                    0.58  2007
# 2           0.144             61851                    0.58  2009
# 3           0.148             10929                    0.89  2011
# 4           0.108              7568                    0.65  2016
# 5           0.087              6396                    0.52  2020
# 0           0.303              1377                    1.51  1985
# 1           0.094              5376                    0.56  1987
# 2           0.118              6431                    0.71  1989
# 3           0.206              1073                    1.03  1991
# 4           0.118              6573                    0.71  1992
# 5           0.171              9642                    1.02  1997
# 6           0.121              1043                    0.96  1999
# 7           0.129              7841                    0.64  2002
# 8           0.127              8589                    0.76  2007
# 9           0.143             10525                    0.86  2011
# 0           0.177               783                    0.88  2009
# 1           0.101              7470                    0.61  2011
# 2           0.094              6562                    0.56  2016
# 3           0.081              5929                    0.48  2020
# 0           0.168              1105                    1.17  1999
# 1           0.167              1478                    1.17  2004
# 2           0.171             11600                    1.03  2007
# 3           0.092              6762                    0.55  2011
# 4           0.278             18572                    0.56  2015
# 5           0.134              9366                    0.80  2016
# 6           0.103              7550                    0.62  2020
# 0           0.038              2568                    0.23  2007
# 1           0.062             26567                    0.25  2009
# 2           0.062               667                    0.50  2009
# 3           0.055              4075                    0.33  2011
# 4           0.098               952                    0.69  2014
# 5           0.162             10806                    0.32  2015
# 6           0.124              8700                    0.75  2016
# 7           0.238             17493                    1.43  2020
# 0           0.061               220                    0.37  1999
#
#                    candidate        constituency election_type candid_id
# 0                 Ann Phelan          Thomastown         LOCAL         1
# 1                 Ann Phelan          Thomastown         LOCAL         1
# 2                 Ann Phelan     Carlow–Kilkenny       GENERAL         1
# 3                 Ann Phelan     Carlow–Kilkenny       GENERAL         1
# 0            John McGuinness     Carlow–Kilkenny       GENERAL         2
# 1            John McGuinness           Tullaroan         LOCAL         2
# 2            John McGuinness           Tullaroan         LOCAL         2
# 3            John McGuinness     Carlow–Kilkenny       GENERAL         2
# 4            John McGuinness            Kilkenny         LOCAL         2
# 5            John McGuinness     Carlow–Kilkenny       GENERAL         2
# 6            John McGuinness     Carlow–Kilkenny       GENERAL         2
# 7            John McGuinness     Carlow–Kilkenny       GENERAL         2
# 8            John McGuinness     Carlow–Kilkenny       GENERAL         2
# 9            John McGuinness     Carlow–Kilkenny       GENERAL         2
# 0           John Paul Phelan             Piltown         LOCAL         3
# 1           John Paul Phelan     Carlow–Kilkenny       GENERAL         3
# 2           John Paul Phelan                East      EUROPEAN         3
# 3           John Paul Phelan     Carlow–Kilkenny       GENERAL         3
# 4           John Paul Phelan     Carlow–Kilkenny       GENERAL         3
# 5           John Paul Phelan     Carlow–Kilkenny       GENERAL         3
# 0                 Phil Hogan           Tullaroan         LOCAL         4
# 1                 Phil Hogan     Carlow–Kilkenny       GENERAL         4
# 2                 Phil Hogan     Carlow–Kilkenny       GENERAL         4
# 3                 Phil Hogan           Tullaroan         LOCAL         4
# 4                 Phil Hogan     Carlow–Kilkenny       GENERAL         4
# 5                 Phil Hogan     Carlow–Kilkenny       GENERAL         4
# 6                 Phil Hogan            Kilkenny         LOCAL         4
# 7                 Phil Hogan     Carlow–Kilkenny       GENERAL         4
# 8                 Phil Hogan     Carlow–Kilkenny       GENERAL         4
# 9                 Phil Hogan     Carlow–Kilkenny       GENERAL         4
# 0                Pat Deering              Tullow         LOCAL         5
# 1                Pat Deering     Carlow–Kilkenny       GENERAL         5
# 2                Pat Deering     Carlow–Kilkenny       GENERAL         5
# 3                Pat Deering     Carlow–Kilkenny       GENERAL         5
# 0              Bobby Aylward             Piltown         LOCAL         6
# 1              Bobby Aylward             Piltown         LOCAL         6
# 2              Bobby Aylward     Carlow–Kilkenny       GENERAL         6
# 3              Bobby Aylward     Carlow–Kilkenny       GENERAL         6
# 4              Bobby Aylward     Carlow–Kilkenny   BI-ELECTION         6
# 5              Bobby Aylward     Carlow–Kilkenny       GENERAL         6
# 6              Bobby Aylward     Carlow–Kilkenny       GENERAL         6
# 0          Kathleen Funchion     Carlow–Kilkenny       GENERAL         7
# 1          Kathleen Funchion                East      EUROPEAN         7
# 2          Kathleen Funchion            Kilkenny         LOCAL         7
# 3          Kathleen Funchion     Carlow–Kilkenny       GENERAL         7
# 4          Kathleen Funchion  Kilkenny City-West         LOCAL         7
# 5          Kathleen Funchion     Carlow–Kilkenny   BI-ELECTION         7
# 6          Kathleen Funchion     Carlow–Kilkenny       GENERAL         7
# 7          Kathleen Funchion     Carlow–Kilkenny       GENERAL         7
# 0  Jennifer Murnane O'Connor        Carlow No. 2         LOCAL         8

# %%
list_of_dataframes
# Out:
# []
